# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
# * 利用 urllib 套件的 urlretrieve 方法下載檔案
# * 了解 Python File I/O 讀檔、寫檔的用法
# * 能用運用資源管理器 With Statement 優化寫法

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# %%
import requests
import json
import pandas as pd

# %%
r_pop = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')
r_npop = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=false')

resp_pop = r_pop.text
resp_npop = r_npop.text

#data_pop = json.loads(resp_pop)
#data_npop = json.loads(resp_npop)
df_pop = pd.read_json(resp_pop)
df_npop = pd.read_json(resp_npop)

# %%
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
print('熱門文章有%s筆資料\n' % len(df_pop))
print('非熱門文章有%s筆資料\n' % len(df_npop))
# Out:
# 熱門文章有30筆資料
#
# 非熱門文章有30筆資料

# %%
cols_name = ['標題', '貼文時間', '留言人數', '按讚人數']

# %%
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」

# 熱門文章
df_pop_r = df_pop[['title', 'createdAt', 'commentCount', 'likeCount']]
df_pop_r.columns = cols_name
print('熱門文章:\n')
df_pop_r
# Out:
# 熱門文章:
#                   標題                      貼文時間  留言人數  按讚人數
# 0           我養到別人家的貓  2019-11-27T02:15:28.197Z    20   494
# 1             哪裡來的天使  2019-11-27T03:55:26.087Z     7   386
# 2         最近刺蝟有點苦惱……  2019-11-27T14:09:04.187Z     9   303
# 3         有沒有人想要認養貓😢  2019-11-27T04:05:54.907Z    16   215
# 4               貓咪送養  2019-11-27T15:53:37.579Z     6    89
# 5         我好像養了一顆球（？  2019-11-27T02:51:29.228Z     8    58
# 6               跪求原圖  2019-11-27T09:03:30.781Z     6    44
# 7      教不到2天就會握手的貓？！  2019-11-27T19:05:47.181Z    14    43
# 8            可愛ㄉ米克斯🐶  2019-11-27T03:08:52.535Z    10    42
# 9      小cookie 一歲生日嘍  2019-11-27T13:29:28.841Z     2    41
# 10                黑貓  2019-11-27T01:46:18.916Z     4    41
# 11          這些狗你認識嗎😍  2019-11-28T04:08:18.539Z     6    34
# 12           兔子吃草a跩樣  2019-11-27T17:48:07.040Z     1    28
# 13              送養貓咪  2019-11-27T14:33:01.950Z     2    28
# 14            開箱ㄐㄅ貓貓  2019-11-27T16:20:13.198Z     1    26
# 15   #更新  尋貓啟示（拜託幫幫忙  2019-11-27T02:42:25.099Z     2    26
# 16               耐ㄍ⋯  2019-11-27T16:36:38.742Z     7    22
# 17             幼貓送養文  2019-11-28T02:52:25.651Z     3    19
# 18      尋貓啟示#台南永康南應大  2019-11-27T11:11:21.836Z     4    19
# 19         充滿柴柴的人生❤️  2019-11-28T07:19:45.391Z     2    18
# 20        蛇蛇吃飯（不喜勿入喔  2019-11-27T07:36:04.550Z     4    18
# 21          妳的柯基犬很可愛  2019-11-27T12:15:40.192Z    12    16
# 22         ［協助汪星人回家］  2019-11-27T02:13:43.258Z     0    16
# 23   貓咪要如何避免被自己的💩臭死？  2019-11-27T14:33:19.704Z     2    14
# 24        高科大校板的遺失倉鼠  2019-11-28T05:23:12.530Z     0    13
# 25    終於知道去哪裡學來的睡姿⋯⋯  2019-11-27T08:59:09.803Z     8    12
# 26          睡姿同步之雙傻組  2019-11-27T00:56:58.462Z     1    11
# 27  #募款 #貓 愛在街角，守護浪貓  2019-11-28T07:11:04.741Z     1     9
# 28              協尋幼犬  2019-11-28T03:29:33.883Z     1     9
# 29            貓咪後腳內八  2019-11-27T11:41:07.570Z     1     9

# %%
# 非熱門文章
df_npop_r = df_npop[['title', 'createdAt', 'commentCount', 'likeCount']]
df_npop_r.columns = cols_name
print('非熱門文章:\n')
df_npop_r
# Out:
# 非熱門文章:
#                   標題                      貼文時間  留言人數  按讚人數
# 0             紙袋破壞王🏆  2019-11-28T09:43:33.709Z     0     0
# 1            讓人心累的主子  2019-11-28T09:34:10.757Z     0     0
# 2         我們哥運動完很餓啦！  2019-11-28T09:31:15.628Z     0     1
# 3          請問這樣算不算虐貓  2019-11-28T09:04:40.825Z     3     1
# 4         #急 新手養鬥魚求救  2019-11-28T08:59:16.234Z     1     1
# 5              這是受傷嗎  2019-11-28T08:29:37.760Z     0     1
# 6          小急）請問莫絲種植  2019-11-28T08:08:57.805Z     2     1
# 7    挑戰極限的塞食物(๑˙❥˙๑)  2019-11-28T07:55:21.256Z     1     2
# 8          充滿柴柴的人生❤️  2019-11-28T07:19:45.391Z     2    18
# 9   #募款 #貓 愛在街角，守護浪貓  2019-11-28T07:11:04.741Z     1     9
# 10     當我的貓和海豹都是一個囧臉  2019-11-28T05:35:09.787Z     1     7
# 11        高科大校板的遺失倉鼠  2019-11-28T05:23:12.530Z     0    13
# 12          兩隻貓咪相處問題  2019-11-28T04:37:32.223Z     2     0
# 13          這些狗你認識嗎😍  2019-11-28T04:08:18.539Z     6    34
# 14           👻我的隱形貓貓  2019-11-28T03:34:49.818Z     1     4
# 15           走失的寵物狗🦮  2019-11-28T03:32:03.781Z     0     5
# 16             求吸鴨地點  2019-11-28T03:29:49.177Z     3     7
# 17              協尋幼犬  2019-11-28T03:29:33.883Z     1     9
# 18              走失狗狗  2019-11-28T03:23:31.964Z     1     4
# 19             幼貓送養文  2019-11-28T02:52:25.651Z     3    19
# 20            🆘巴西龜龜殼  2019-11-27T19:43:15.143Z     4     0
# 21      倉鼠一天到晚自己跑去洗澡  2019-11-27T19:26:11.368Z     2     2
# 22     教不到2天就會握手的貓？！  2019-11-27T19:05:47.181Z    15    43
# 23           兔子吃草a跩樣  2019-11-27T17:48:07.040Z     1    28
# 24         我家的貓會握手了！  2019-11-27T16:47:38.502Z     2     7
# 25      我家阿北有老人味🦜 求解  2019-11-27T16:39:41.215Z     4     8
# 26               耐ㄍ⋯  2019-11-27T16:36:38.742Z     7    22
# 27             求領養🙏🏼  2019-11-27T16:26:53.184Z     0     8
# 28            開箱ㄐㄅ貓貓  2019-11-27T16:20:13.198Z     1    27
# 29              貓咪送養  2019-11-27T15:53:37.579Z     6    89

# %%
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」
print('熱門文章-平均留言人數:', df_pop_r['留言人數'].mean())
print('熱門文章-平均按讚人數:', df_pop_r['按讚人數'].mean())
print('非熱門文章-平均留言人數:', df_npop_r['留言人數'].mean())
print('非熱門文章-平均按讚人數:', df_npop_r['按讚人數'].mean())
# Out:
# 熱門文章-平均留言人數: 5.333333333333333
# 熱門文章-平均按讚人數: 70.1
# 非熱門文章-平均留言人數: 2.3333333333333335
# 非熱門文章-平均按讚人數: 12.333333333333334
